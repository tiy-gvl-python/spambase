# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.cross_validation import train_test_split 
from sklearn.naive_bayes import MultinomialNB

# %%
with open("spambase/spambase.names") as doc:
    vars = doc.readlines()[33:]
vars = [var.split(":")[0] for var in vars]
vars.append('spam_bool')
vars
# Out:
# ['word_freq_make',
#  'word_freq_address',
#  'word_freq_all',
#  'word_freq_3d',
#  'word_freq_our',
#  'word_freq_over',
#  'word_freq_remove',
#  'word_freq_internet',
#  'word_freq_order',
#  'word_freq_mail',
#  'word_freq_receive',
#  'word_freq_will',
#  'word_freq_people',
#  'word_freq_report',
#  'word_freq_addresses',
#  'word_freq_free',
#  'word_freq_business',
#  'word_freq_email',
#  'word_freq_you',
#  'word_freq_credit',
#  'word_freq_your',
#  'word_freq_font',
#  'word_freq_000',
#  'word_freq_money',
#  'word_freq_hp',
#  'word_freq_hpl',
#  'word_freq_george',
#  'word_freq_650',
#  'word_freq_lab',
#  'word_freq_labs',
#  'word_freq_telnet',
#  'word_freq_857',
#  'word_freq_data',
#  'word_freq_415',
#  'word_freq_85',
#  'word_freq_technology',
#  'word_freq_1999',
#  'word_freq_parts',
#  'word_freq_pm',
#  'word_freq_direct',
#  'word_freq_cs',
#  'word_freq_meeting',
#  'word_freq_original',
#  'word_freq_project',
#  'word_freq_re',
#  'word_freq_edu',
# ...

# %%
df = pd.read_csv("spambase/spambase.data", names=vars)
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64             0
# 1            0.21               0.28           0.50             0
# 2            0.06               0.00           0.71             0
# 3            0.00               0.00           0.00             0
# 4            0.00               0.00           0.00             0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail    ...      char_freq_;  char_freq_(  \
# ...

# %% [markdown]
# ## Using Sklearn train, test, split to Split matrices into test and train subsets.

# %%
train, test = train_test_split(df, test_size=0.4)

# %%
train.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 3723               0                  0           0.00             0
# 2447               0                  0           0.00             0
# 312                0                  0           0.16             0
# 4585               0                  0           0.00             0
# 3518               0                  0           0.00             0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 3723           0.00            0.00              0.00                   0
# 2447           0.00            0.00              0.00                   0
# 312            0.16            0.00              0.16                   0
# 4585           0.00            0.00              0.00                   0
# 3518           0.24            0.49              0.00                   0
#
#       word_freq_order  word_freq_mail    ...      char_freq_;  char_freq_(  \
# ...

# %%
test.head()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 1888               0                  0           0.00             0
# 2715               0                  0           0.27             0
# 3883               0                  0           0.00             0
# 2692               0                  0           0.00             0
# 3302               0                  0           0.48             0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 1888           0.69               0                 0                   0
# 2715           0.00               0                 0                   0
# 3883           0.00               0                 0                   0
# 2692           0.00               0                 0                   0
# 3302           2.18               0                 0                   0
#
#       word_freq_order  word_freq_mail    ...      char_freq_;  char_freq_(  \
# ...

# %%
train_y = train[train.columns[-1]]

# %%
train_y.head()
# Out:
# 1320    1
# 4136    0
# 1030    1
# 2742    0
# 1352    1
# Name: spam_bool, dtype: int64

# %%
test_y = test[test.columns[-1]]

# %%
test_y.head()
# Out:
# 2463    0
# 2878    0
# 3704    0
# 1212    1
# 534     1
# Name: spam_bool, dtype: int64

# %%
classifier = MultinomialNB()

# %%
classifier.fit(train, train_y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ##Conclusion

# %% [markdown]
# ###Given that our classifier score was greater than 0.8 we can determine that we can accurately predict the occurance of spam text.

# %%
classifier.score(test, test_y)
# Out:
# 0.84573601303639323
